# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %% [markdown]
# # Загрузка данных
# **Список полей**
# - Район
# - Улица
# - Цена
# - Количество комнат
# - Общая площадь
# - Площадь кухни
# - Этаж
# - Балкон или лоджия
# - Тип комнат
# - Санузел
# - Ремонт
# - Мебель
# - Техника
# - Интернет и ТВ
# - Можно с детьми
# - Можно с животными
# - Можно курить
# - Тип дома
# - Этажей в доме
# - Пассажирский лифт
# - Грузовой лифт
# - Лифт
# - Парковка

# %%
apartments = pd.read_csv("Data/kursk_apartments.csv", index_col=0)
apartments.head()
# Out:
#              Район     Цена  Количество комнат  Общая площадь  Площадь кухни  \
# 0  р-н Центральный  35000.0                  3          116.0           20.0
# 1  р-н Центральный  27000.0                  3           80.0           15.0
# 2  р-н Центральный  12000.0                  2           58.0           12.0
# 3  р-н Центральный  13000.0                  2           75.0           15.0
# 4  р-н Центральный  15000.0                  3           85.0           13.0
#
#    Этаж Балкон или лоджия              Тип комнат      Санузел         Ремонт  \
# 0     5    балкон, лоджия           изолированные   раздельный           евро
# 1     2            балкон           изолированные  совмещенный           евро
# 2     1            балкон           изолированные   раздельный  косметический
# 3     5            лоджия           изолированные          NaN  косметический
# 4     9            лоджия  изолированные, смежные   раздельный           евро
#
#    ... Можно с детьми Можно с животными Можно курить    Тип дома  \
# 0  ...              1                 0            0   кирпичный
# 1  ...              1                 0            0   кирпичный
# 2  ...              1                 0            0   панельный
# 3  ...              1                 0            0  монолитный
# 4  ...              1                 0            0   панельный
#
#    Этажей в доме  Пассажирский лифт Грузовой лифт                Парковка  \
# 0              9                  1             0  за шлагбаумом во дворе
# 1              5                  0             0  за шлагбаумом во дворе
# 2             17                  1             1       открытая во дворе
# 3             10                  1             0       открытая во дворе
# 4             10                  0             0       открытая во дворе
#
#    Лифт                   Улица
# 0     1     ул. Карла Либкнехта
# 1     0             Красная пл.
# 2     1  пр-т Вячеслава Клыкова
# 3     1             пр-т Победы
# 4     0        Студенческая ул.
#
# [5 rows x 23 columns]

# %%
apartments = apartments[(
    np.abs(stats.zscore(apartments[['Цена', 'Общая площадь']])) < 2).all(axis=1)]
apartments.dropna(subset=['Цена', 'Общая площадь'], how='all', inplace=True)
apartments.shape
# Out:
# (203, 23)

# %%
apartments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203 entries, 1 to 216
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Район              203 non-null    object
#  1   Цена               203 non-null    float64
#  2   Количество комнат  203 non-null    int64
#  3   Общая площадь      203 non-null    float64
#  4   Площадь кухни      203 non-null    float64
#  5   Этаж               203 non-null    int64
#  6   Балкон или лоджия  157 non-null    object
#  7   Тип комнат         96 non-null     object
#  8   Санузел            175 non-null    object
#  9   Ремонт             203 non-null    object
#  10  Мебель             169 non-null    object
#  11  Техника            180 non-null    object
#  12  Интернет и ТВ      94 non-null     object
#  13  Можно с детьми     203 non-null    int64
#  14  Можно с животными  203 non-null    int64
#  15  Можно курить       203 non-null    int64
#  16  Тип дома           203 non-null    object
#  17  Этажей в доме      203 non-null    int64
#  18  Пассажирский лифт  203 non-null    int64
#  19  Грузовой лифт      203 non-null    int64
#  20  Парковка           144 non-null    object
#  21  Лифт               203 non-null    int64
#  22  Улица              203 non-null    object
# dtypes: float64(3), int64(9), object(11)
# memory usage: 38.1+ KB

# %%
apartments.describe()
# Out:
#                Цена  Количество комнат  Общая площадь  Площадь кухни  \
# count    203.000000         203.000000     203.000000     203.000000
# mean   14438.423645           1.640394      48.432512      10.790640
# std     5470.207471           0.892068      14.505654       5.769943
# min     5000.000000           1.000000      16.000000       2.000000
# 25%    10000.000000           1.000000      38.000000       8.000000
# 50%    13000.000000           1.000000      44.000000      10.000000
# 75%    17000.000000           2.000000      58.000000      11.200000
# max    30000.000000           9.000000      85.000000      56.400000
#
#              Этаж  Можно с детьми  Можно с животными  Можно курить  \
# count  203.000000      203.000000         203.000000     203.00000
# mean     5.743842        0.679803           0.137931       0.08867
# std      3.747395        0.467706           0.345680       0.28497
# min      1.000000        0.000000           0.000000       0.00000
# 25%      3.000000        0.000000           0.000000       0.00000
# 50%      5.000000        1.000000           0.000000       0.00000
# 75%      8.000000        1.000000           0.000000       0.00000
# max     17.000000        1.000000           1.000000       1.00000
#
#        Этажей в доме  Пассажирский лифт  Грузовой лифт        Лифт
# count     203.000000         203.000000     203.000000  203.000000
# mean       10.990148           0.605911       0.374384    0.640394
# std         4.856342           0.489862       0.485160    0.481071
# min         2.000000           0.000000       0.000000    0.000000
# 25%         9.000000           0.000000       0.000000    0.000000
# 50%        10.000000           1.000000       0.000000    1.000000
# 75%        17.000000           1.000000       1.000000    1.000000
# max        18.000000           1.000000       1.000000    1.000000

# %% [markdown]
# # Гипотезы
# 1. Цена квартиры зависит от общей площади и площади кухни
# 2. Цена квартиры зависит от улицы
# 3. Цена квартиры зависит от типа парковки
# 4. Цена квартиры зависит от типа комнат
# 5. Цена квартиры зависит от ремонта
# 6. Цена квартиры зависит от мебели
# 7. Цена квартиры зависит от техники

# %% [markdown]
# ## Target
# Для начала необходимо изучить целевую переменную

# %%
plt.figure(figsize=(15, 5))

sns.kdeplot((apartments['Цена']), fill=True)
# plt.axvline(apartments['Цена'].median(), label=f'median {apartments["Цена"].median()}', color='red', linestyle='--')
# plt.axvline(apartments['Цена'].quantile(0.25) , label=f'median {apartments["Цена"].median()}', color='green', linestyle='--')
# plt.axvline(apartments['Цена'].quantile(0.75) , label=f'median {apartments["Цена"].median()}', color='green', linestyle='--')
plt.show()

# %%
stats.shapiro(apartments['Цена'])
# Out:
# ShapiroResult(statistic=0.9198721647262573, pvalue=4.6588284341453345e-09)

# %% [markdown]
# Целевая переменная не имеет нормального распределения, поэтому ее логарифмируем

# %%
sns.kdeplot((np.log2(apartments['Цена'])), fill=True)
plt.show()

# %%
stats.shapiro(np.log2(apartments['Цена']))
# Out:
# ShapiroResult(statistic=0.9837433099746704, pvalue=0.019235186278820038)

# %% [markdown]
# Даже после логарифмирования p-значение меньше 0.05. Вероятность для получения таких результатов при условии нормальности распределения очень мала. Таким образом, можно сказать, что распределение не является нормальным.

# %% [markdown]
# ## Общая площадь и площадь кухни влияет на стоимость аренды квартиры

# %%
df1_features = ['Цена', 'Общая площадь', 'Площадь кухни']
df1 = apartments[df1_features].copy()
df1.describe()
# Out:
#                Цена  Общая площадь  Площадь кухни
# count    203.000000     203.000000     203.000000
# mean   14438.423645      48.432512      10.790640
# std     5470.207471      14.505654       5.769943
# min     5000.000000      16.000000       2.000000
# 25%    10000.000000      38.000000       8.000000
# 50%    13000.000000      44.000000      10.000000
# 75%    17000.000000      58.000000      11.200000
# max    30000.000000      85.000000      56.400000

# %%
sns.heatmap(df1.corr(), square=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Округляем цену и площади для более сглаженного отображения зависимостей
df1['Цена'] = df1['Цена'].apply(lambda x: x-500 if x % 1000 > 0 else x)
df1['Общая площадь'] = df1['Общая площадь'].round(0).astype(int)
df1['Площадь кухни'] = df1['Площадь кухни'].round(0).astype(int)

# %%
plt.subplots(figsize=(20, 5))
sns.boxplot(y='Общая площадь', x='Цена', data=df1)
# Out:
# <AxesSubplot:xlabel='Цена', ylabel='Общая площадь'>

# %%
plt.subplots(figsize=(20, 5))
sns.boxplot(y='Площадь кухни', x='Цена', data=df1)
# Out:
# <AxesSubplot:xlabel='Цена', ylabel='Площадь кухни'>

# %% [markdown]
# Цена коррелирует с общей площадью, в то время как зависимость цены и площади кухни явно не выражена. Также площадь кухни сильно коррелирует с общей площадью квартиры, следовательно для построения модели стоит учитывать только общую площадь.

# %% [markdown]
# ## Местоположение квартиры влияет на цену ее аренды

# %%
# TODO make by pep8 standart
min_occurances_postalcodes = 10
min_occurances_locations = 5

# %%
df2_features = ['Цена', 'Улица', 'Район']
df2 = apartments[df2_features].copy()

# %% [markdown]
# Почтовый индекс разбивает записи на большие группы, чем улица, в следствие чего зависимость может отличаться.

# %%
with open("Utilities/PostalcodesSearch/locations_postalcodes.json", encoding='utf-8') as file:
    locations_postalcodes = json.load(file)

# %%
df2['Почтовый индекс'] = df2['Улица'].apply(lambda x: locations_postalcodes[x])
df2.isnull().sum()
# Out:
# Цена               0
# Улица              0
# Район              0
# Почтовый индекс    0
# dtype: int64

# %% [markdown]
# ### Зависимость цены от почтового индекса

# %%
apartments_indexes = df2.groupby('Почтовый индекс')['Почтовый индекс'].agg(
    'count').sort_values(ascending=False)
apartments_indexes[apartments_indexes < min_occurances_postalcodes].sum()
# Out:
# 48

# %%
df2['Почтовый индекс'] = df2['Почтовый индекс'] \
    .apply(lambda x: x if x in apartments_indexes[apartments_indexes >= min_occurances_postalcodes] else 'другой')

df2['Почтовый индекс'].value_counts()
# Out:
# другой    48
# 305000    29
# 305006    28
# 305021    24
# 305005    23
# 305004    19
# 305018    12
# 305016    10
# 305001    10
# Name: Почтовый индекс, dtype: int64

# %%
plt.figure(figsize=(5, 6))
sns.boxplot(y='Почтовый индекс', x='Цена', data=df2.sort_values(by='Цена'))
# Out:
# <AxesSubplot:xlabel='Цена', ylabel='Почтовый индекс'>

# %% [markdown]
# Зависимость цены на аренду квартиры от почтового индекса присутствует, можно выделить индексы, цена для которых будет как ниже, так и выше средних значений.

# %% [markdown]
# ### Зависимость цены от улицы

# %%
apartments_locations = df2.groupby('Улица')['Улица'].agg(
    'count').sort_values(ascending=False)
apartments_locations[apartments_locations < min_occurances_locations].sum()
# Out:
# 104

# %%
df2['Улица'] = df2['Улица'] \
    .apply(lambda x: 'другая' if x in apartments_locations[apartments_locations < min_occurances_locations] else x)

df2['Улица'].value_counts()
# Out:
# другая                       104
# пр-т Анатолия Дериглазова     22
# пр-т Победы                   19
# пр-т Вячеслава Клыкова        18
# пр-т Ленинского Комсомола      8
# ул. Радищева                   6
# ул. Домостроителей             6
# пр-т Надежды Плевицкой         5
# ул. Карла Маркса               5
# ул. Ленина                     5
# ул. Димитрова                  5
# Name: Улица, dtype: int64

# %%
plt.figure(figsize=(5, 8))
sns.boxplot(y='Улица', x='Цена', data=df2.sort_values(by='Цена'))
# Out:
# <AxesSubplot:xlabel='Цена', ylabel='Улица'>

# %% [markdown]
# Зависимость цены на аренду квартиры от улицы присутствует, но не смотря на это, более чем для половины датасета недостаточно данных, чтобы делать выводы о средних значениях цены по улицам.

# %% [markdown]
# ### Зависимость цены от района

# %%
df3_features = ['Район', 'Цена']
df3 = apartments[df3_features].copy()
df3['Район'].value_counts()
# Out:
# р-н Центральный        177
# р-н Сеймский            22
# р-н Железнодорожный      4
# Name: Район, dtype: int64

# %%
sns.boxplot(x='Район', y='Цена', data=df2)
# Out:
# <AxesSubplot:xlabel='Район', ylabel='Цена'>

# %% [markdown]
# По графику видно, что в Сеймском районе цена в среднем ниже, чем в других районах города.
# В Центральном сдаются квартиры всех ценовых категорий, а для Железнодорожного данных о ценах на квартиру недостаточно.
#
# Цена квартиры коррелирует с ее местоположением, что лучше всего видно по разбиению на почтовые индексы.

# %% [markdown]
# ## Тип комнат влияет на цену аренды квартиры

# %%
df5_features = ['Цена', 'Тип комнат', 'Общая площадь']
df5 = apartments[df5_features].copy()
df5['Тип комнат'].value_counts()
# Out:
# изолированные             85
# смежные                    9
# изолированные, смежные     2
# Name: Тип комнат, dtype: int64

# %%
df5['Тип комнат'] = df5['Тип комнат'].apply(
    lambda x: str(x).replace(', ', ','))
df5['Тип комнат'] = df5['Тип комнат'].apply(
    lambda x: 'не указан' if x == 'nan' else x)

df5_dummies = pd.concat(
    [df5['Цена'], df5['Тип комнат'].str.get_dummies(sep=",")], axis=1)

df5_dummies.drop('Цена', axis=1).sum()
# Out:
# изолированные     87
# не указан        107
# смежные           11
# dtype: int64

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(10, 10))
plt.title(f'Корреляция цены и типов комнат', y=1.05, size=15)
sns.heatmap(df5_dummies.corr(), square=True, annot=True, cmap=colormap)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.title(f'Зависимость цены от типа комнат', y=1.05, size=15)
sns.boxplot(x='Тип комнат', y='Цена', data=df5, color='lightgreen')
plt.axhline(df5['Цена'].median(), label=f'median {df5["Цена"].median()}', linestyle='--')
plt.axhspan(df5['Цена'].quantile(0.25), df5['Цена'].quantile(0.75), alpha=0.2, label='0.25-0.75 quantile')
plt.legend(loc='upper right')

# %% [markdown]
# Изолированные комнаты, имеют цену выше медианы, однако, у них большая дисперсия.
# Объявления, в которых не указан тип комнаты, больше половины, и они по цене располагаются ниже медианы.
# Данных для смежных комнат недостаточно, чтобы по ним можно было сделать вывод.
#
# Для модели не стоит использовать тип комнат.

# %% [markdown]
# ## Тип ремонта влияет на стоимост ьаренды квартиры

# %%
df6_features = ['Цена','Ремонт']
df6 = apartments[df6_features].copy()
df6['Ремонт'].value_counts()
# Out:
# косметический    135
# евро              55
# дизайнерский      13
# Name: Ремонт, dtype: int64

# %%
df6_dummies = pd.get_dummies(df6, 'Ремонт')

plt.figure(figsize=(10, 10))
plt.title(f'Корреляция цены и ремонта', y=1.05, size=15)
sns.heatmap(df6_dummies.corr(), square=True, annot=True, cmap=colormap)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title(f'Зависимость цены от ремонта', y=1.05, size=15)
sns.boxplot(y='Ремонт', x='Цена', data=df6)
# Out:
# <AxesSubplot:title={'center':'Зависимость цены от ремонта'}, xlabel='Цена', ylabel='Ремонт'>

# %% [markdown]
# На графике прослеживается зависимость между типами ремонта и ценой на аренду квартиры.
# Этот параметр стоит учитывать для построения модели.

# %% [markdown]
# ## Мебель в квартире влияет на цену ее аренды.

# %%
df7_features = ['Цена','Мебель']
df7 = apartments[df7_features].copy()
df7['Мебель'].value_counts()
# Out:
# кухня, хранение одежды, спальные места    143
# кухня, спальные места                      12
# кухня                                       8
# кухня, хранение одежды                      4
# хранение одежды, спальные места             2
# Name: Мебель, dtype: int64

# %%
df7['Мебель'] = df7['Мебель'].apply(
    lambda x: str(x).replace(', ', ','))

df7_dummies = pd.concat(
    [df7['Цена'], df7['Мебель'].str.get_dummies(sep=",")], axis=1)

df7_dummies.drop('Цена', axis=1).sum()
# Out:
# nan                 34
# кухня              167
# спальные места     157
# хранение одежды    149
# dtype: int64

# %%
plt.figure(figsize=(10, 10))
plt.title(f'Корреляция цены и мебели', y=1.05, size=15)
sns.heatmap(df7_dummies.corr(), square=True, annot=True, cmap=colormap)
plt.show()

# %%
def transform_furniture(row):
    row['кухня'] = row['Цена'] if row['кухня'] == 1 else None
    row['хранение одежды'] = row['Цена'] if row['хранение одежды'] == 1 else None
    row['спальные места'] = row['Цена'] if row['спальные места'] == 1 else None
    row['nan'] = row['Цена'] if row['nan'] == 1 else None
    return row

plt.figure(figsize=(12,6))
sns.boxplot(data=df7_dummies.apply(transform_furniture, axis=1).drop('Цена', axis=1))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(6,6))
df7_binary = df7.copy()
df7_binary['Мебель'] = df7_binary['Мебель'].apply(lambda x: 'хранение одежды' if 'хранение одежды' in str(x) else 'остальное')
sns.boxplot(y='Цена', x='Мебель', data=df7_binary)
# Out:
# <AxesSubplot:xlabel='Мебель', ylabel='Цена'>

# %%
#ToDO переписать по клин коду или удалить
# хз зачем тут нужна вся эта шляпа
axs = plt.subplots(1,3, sharey=True, figsize=(16, 8))
for n, column in enumerate(['кухня','хранение одежды','спальные места']):
    ax = plt.subplot(1,3,  n + 1)
    sns.boxplot(y=df7['Цена'], x=df7['Мебель'].apply(lambda x: column if column in str(x) else 'остальное'),ax=ax, color='lightgreen')
    plt.axhline(df7['Цена'].median(), label=f'median {df7["Цена"].median()}', linestyle='--')
    plt.axhspan(df7['Цена'].quantile(0.25), df7['Цена'].quantile(0.75), alpha=0.2, label='0.25-0.75 quantile')
    plt.legend()
plt.show()

# %%
# Todo накидать мол для кухни все хуйня они не сильно отличаются, да и разброс большой, а для одежды и спальных заебись, там отличие поболее будет, в модельку пойдут.
# И что спальные и одежду вместе не стоит в модель пихать, они ж не отличаются особо, а то шляпа получится.

# %% [markdown]
# ## Техника в квартире влияет на цену ее аренды

# %%
df8_features = ['Цена','Техника']
df8 = apartments[df8_features].copy()
df8['Техника'].value_counts()
# Out:
# холодильник, плита, стиральная машина, телевизор                                                                       33
# холодильник, плита, стиральная машина                                                                                  26
# холодильник, плита, микроволновка, стиральная машина, телевизор                                                        22
# холодильник, плита, микроволновка, стиральная машина                                                                   14
# холодильник, плита                                                                                                     12
# плита                                                                                                                  10
# холодильник, плита, телевизор                                                                                           9
# кондиционер, холодильник, плита, микроволновка, стиральная машина, телевизор                                            6
# холодильник, плита, микроволновка, стиральная машина, водонагреватель, телевизор                                        5
# холодильник, стиральная машина                                                                                          5
# кондиционер, холодильник, плита, микроволновка, стиральная машина, посудомоечная машина, водонагреватель, телевизор     4
# холодильник, плита, стиральная машина, водонагреватель                                                                  3
# холодильник, плита, стиральная машина, водонагреватель, телевизор                                                       3
# холодильник, стиральная машина, телевизор                                                                               3
# кондиционер, холодильник, плита, микроволновка, стиральная машина                                                       3
# кондиционер, холодильник, плита, микроволновка, стиральная машина, посудомоечная машина, телевизор                      2
# кондиционер, холодильник, плита, микроволновка, стиральная машина, водонагреватель, телевизор                           2
# кондиционер, холодильник, плита, стиральная машина, телевизор                                                           2
# холодильник, плита, микроволновка, стиральная машина, посудомоечная машина, водонагреватель, телевизор                  2
# холодильник, микроволновка, стиральная машина, телевизор                                                                2
# плита, стиральная машина                                                                                                2
# плита, стиральная машина, телевизор                                                                                     1
# кондиционер, холодильник, плита, стиральная машина                                                                      1
# холодильник, плита, микроволновка, стиральная машина, посудомоечная машина, телевизор                                   1
# холодильник, микроволновка, стиральная машина                                                                           1
# кондиционер, холодильник, плита, микроволновка, водонагреватель                                                         1
# холодильник, плита, посудомоечная машина, водонагреватель                                                               1
# кондиционер, плита, стиральная машина, водонагреватель                                                                  1
# кондиционер, плита, микроволновка, стиральная машина, телевизор                                                         1
# кондиционер, холодильник, плита, стиральная машина, водонагреватель, телевизор                                          1
# холодильник, плита, микроволновка, стиральная машина, фен, утюг                                                         1
# Name: Техника, dtype: int64

# %%
df8['Техника'] = df8['Техника'].apply(
    lambda x: str(x).replace(', ', ',') if str(x) != 'nan' else x)

df8_dummies = pd.concat(
    [df8['Цена'], df8['Техника'].str.get_dummies(sep=",")], axis=1)

plt.figure(figsize=(10, 10))
plt.title(f'Корреляция цены и техники', y=1.05, size=15)
sns.heatmap(df8_dummies.corr(), square=True, annot=True, cmap=colormap)
plt.show()

# %%
# Todo Посмотреть на текущую модель и привести эту часть анализа под ее результаты.

# %%
# ToDo написать нормально мол это поле используем в модели, но удаляем плиту и холодильник потому что там большая корреляция со стиральной машиной
# удаляем фен и утюг потому что там нет зависимости

# %% [markdown]
# # Проверка оставшихся полей хитмапом (перефразировать)

# %%
other_features = ['Цена', 'Лифт', 'Пассажирский лифт', 'Грузовой лифт', 'Балкон или лоджия', 'Количество комнат',
                  'Можно с детьми', 'Можно с животными', 'Можно курить', 'Этаж', 'Этажей в доме', 'Общая площадь']
df_other = apartments[other_features].copy()

# %%
def contains_substring_to_binary(value, substring):
    if value is None:
        return 0
    if substring in str(value):
        return 1
    return 0


df_other['Балкон'] = df_other['Балкон или лоджия'].apply(
    lambda x: contains_substring_to_binary(x, 'балкон'))
df_other['Лоджия'] = df_other['Балкон или лоджия'].apply(
    lambda x: contains_substring_to_binary(x, 'лоджия'))
df_other.drop('Балкон или лоджия', axis=1, inplace=True)

# %%
plt.figure(figsize=(10, 10))
plt.title(f'Попарная корреляция', y=1.05, size=15)
sns.heatmap(df_other.corr(), square=True, annot=True, cmap=colormap)
plt.show()

# %%
# ToDo чекнуть результаты модели и написать красиво что используем.
#
